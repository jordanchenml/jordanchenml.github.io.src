# %% [markdown]
# Title: Dense Net
# Date: 2020-03-17 13:40
# Category: CNN
# Tags: Implementations
# Slug: Dense Net
# Author: Jordan Chen
# Summary: Implementations of DneseNet

# %% [markdown]
# ## 前言
#
# ResNet模型的出現是CNN史上的一個里程碑，ResNet可以訓練出更深的CNN模型，從而實現更高的準確度。 ResNet模型的核心是通過建立前面層與後面層之間的“短路連接”（shortcuts，skip connection），這有助於訓練過程中梯度的反向傳播，從而能訓練出更深的CNN網絡。以下要介紹的是DenseNet模型，它的基本思路與ResNet一致，但是它建立的是前面所有層與後面層的密集連接（dense connection），它的名稱也是由此而來。 DenseNet的另一大特色是通過特徵在channel上的連接來實現特徵重用（feature reuse）。這些特點讓DenseNet在參數和計算成本更少的情形下實現比ResNet更優的性能，DenseNet也因此斬獲CVPR 2017的最佳論文獎。

# %% [markdown]
# ## DenseNet 架構
# DenseNets分為DenseBlocks，其中要素圖的尺寸在一個塊內保持不變，但是過濾器的數量在它們之間變化。 它們之間的這些層稱為過渡層，並應用批量歸一化，1x1卷積和2x2池化層來進行下採樣。
#
# <img src='https://github.com/jordanchenml/DL_Implementations_with_Tensorflow/blob/master/models/DenseNet/assets/densenet_1.png?raw=true' width=800px>

# %% [markdown]
# ### Dense Blocks
#
# 相比ResNet，DenseNet提出了一個更激進的密集連接機制：即互相連接所有的層，具體來說就是每個層都會接受其前面所有層作為其額外的輸入。以下為ResNet與DenseNet網絡的連接機制，作為對比，可以看到，ResNet是每個層與前面的某層（一般是2~3層）短路連接在一起，連接方式是通過 element-wise 相加。而在DenseNet中，每個層都會與前面所有層在channel維度上連接（concat）在一起（這裡各個層的 feature map 大小是相同的，後面會有說明），並作為下一層的輸入。對於一個 L 層的網絡，DenseNet共包含 L（L + 1）/ 2 個連接，相比ResNet，這是一種密集連接。而且DenseNet是直接連接來自不同層的特徵圖，這可以實現特徵重用，提升效率，這一特點是DenseNet與ResNet最主要的區別。
#
# <img src='https://github.com/jordanchenml/DL_Implementations_with_Tensorflow/blob/master/models/DenseNet/assets/densenet_2.png?raw=true' width=500px>

# %% [markdown]
# 下圖為公式表示之比較
#
# <img src='https://github.com/jordanchenml/DL_Implementations_with_Tensorflow/blob/master/models/DenseNet/assets/densenet_4.png?raw=true' width=800px>

# %% [markdown]
# DenseNet的前向過程如下圖所示，可以更直觀地理解其密集連接方式，比如 h3 的輸入不僅包括來自 h2 的 x2 ，還包括前面兩層的 x0 和 x1 ，它們是在channel維度上連接在一起的。
# <img src='https://github.com/jordanchenml/DL_Implementations_with_Tensorflow/blob/master/models/DenseNet/assets/densenet_3.gif?raw=true' width=800px>

# %% [markdown]
# #### Growth Rate
#
# 由於連接 feature map ，因此 channek 的尺寸在每一層都在增加。 如果我們使 H_1 每次生成 k 個特徵圖，那麼我們可以歸納為第l層為：
#
# <img src='https://github.com/jordanchenml/DL_Implementations_with_Tensorflow/blob/master/models/DenseNet/assets/growth_rate_formula.png?raw=true' width=200px>
#
# 該超參數 k 即是 growth rate。 growth rate調節每層網絡中添加了多少訊息。
# 我們可以將 feature map 視為網絡的訊息。 每個層都可以訪問其先前的 feature map ，因此可以訪問 collective knowledge。 然後，每層都在具體的 k 個 feature map 中將新訊息添加到此 collective knowledge 中

# %% [markdown]
# ### Compression Rate
#
# 對於我們希望減少輸出 feature map 數量的情況。 compression rate 決定了減少的幅度。假設才特定layer上具有m個 feature map ，經過壓縮後的大小為 compression_rate * m。 Compression rate 的範圍是 [0-1]。 因此，當 compression_rate = 1時，DenseNets將保持不變。

# %% [markdown]
# ### Bottleneck Layers
#
# 在進行BN-ReLU-3×3轉換之前，先完成BN-ReLU-1×1轉換。
# bottleneck 的用意在於減少計算量，能使最後輸出的總資料量為 growth rate 乘上最後輸出的量(不含前面重覆連接的部分)，因為密集連接的方式會使得最後一個 channel 的輸出為 n 平方，當堆疊越多時這樣的計算量會照成很大的影響。以 DenseNet_121 第三個Dense Block 為例，若不經過 bottleneck layer 最後一層的輸出為 32\*32。而bottleneck layer 可以把輸出轉為 4*growth_rate = 4*32 = 128，大大降低模型的複雜性和大小。
#
# <img src='https://github.com/jordanchenml/DL_Implementations_with_Tensorflow/blob/master/models/DenseNet/assets/bottleneck.png?raw=true' width=800px>

# %% [markdown]
# ### Transition Layers
# 1×1 Conv 和 2×2 Average Pooling 被用作兩個連續 Dense Block 之間的 transition layer。在 Dense Block 內的 Feature Map 大小相同，因此可以輕鬆地將它們串聯在一起。
#
# <img src='https://github.com/jordanchenml/DL_Implementations_with_Tensorflow/blob/master/models/DenseNet/assets/multipledenseblocks.png?raw=true' width=800px>

# %% [markdown]
# ### Global Average Pooling
#
# 在最後一個密集塊的末尾，執行全局平均池化，然後附加softmax分類器。

# %% [markdown]
# ## Advantages of DenseNet
#
# ### Strong Gradient Flow
# 誤差信號可以很容易地更直接地傳播到較早的層。這是一種隱式的深度監管，因為較早的層可以直接從最終分類層獲得回饋。
#
# <img src='https://github.com/jordanchenml/DL_Implementations_with_Tensorflow/blob/master/models/DenseNet/assets/densenet_5.png?raw=true' width=800px>
#
#
# ### Parameter & Computational Efficiency
# 對於每一層，ResNet 中的參數數量與 C×C 成正比，而 DenseNet 中的參數數量與 l×k×k 成正比。 由於 k << C，DenseNet 的大小比 ResNet 小得多。
#
# <img src='https://github.com/jordanchenml/DL_Implementations_with_Tensorflow/blob/master/models/DenseNet/assets/densenet_6.png?raw=true' width=800px>
#
#
# ### More Diversified Features
# 由於 DenseNet 中的每一層都接收所有先前的層作為輸入，因此特徵更加多樣化。
#
# <img src='https://github.com/jordanchenml/DL_Implementations_with_Tensorflow/blob/master/models/DenseNet/assets/densenet_7.png?raw=true' width=800px>
#
#
# ### Maintains Low Complexity Features
# 在標準ConvNet中，分類器使用最複雜的功能。
#
# <img src='https://github.com/jordanchenml/DL_Implementations_with_Tensorflow/blob/master/models/DenseNet/assets/densenet_8.png?raw=true' width=800px>
#
# 在 DenseNet 中，分類器使用所有復雜度級別的功能。它傾向於給出更平滑的決策邊界。這也解釋了為什麼訓練數據不足時 DenseNet 表現良好。
#
# <img src='https://github.com/jordanchenml/DL_Implementations_with_Tensorflow/blob/master/models/DenseNet/assets/densenet_9.png?raw=true' width=800px>

# %%
try:
    # %tensorflow_version only exists in Colab.
    # %tensorflow_version 2.x
except Exception:
    pass

# %%
# !pip install tensorflow==2.0.0
import tensorflow as tf
tf.config.experimental_run_functions_eagerly(True)
print(tf.__version__)
# Out:
# 2.0.0

# %%
# Parameters
ACCURACY_THRESHOLD = 0.99
NUM_CLASSES = 10
IMAGE_HEIGHT = 32
IMAGE_WIDTH = 32
CHANNELS = 3

# %%
class BottleNeck(tf.keras.layers.Layer):
    def __init__(self, growth_rate, drop_rate):
        super(BottleNeck, self).__init__()
        self.bn1 = tf.keras.layers.BatchNormalization()
        self.conv1 = tf.keras.layers.Conv2D(filters=4 * growth_rate,
                                            kernel_size=(1, 1),
                                            strides=1,
                                            padding="same")
        self.bn2 = tf.keras.layers.BatchNormalization()
        self.conv2 = tf.keras.layers.Conv2D(filters=growth_rate,
                                            kernel_size=(3, 3),
                                            strides=1,
                                            padding="same")
        self.dropout = tf.keras.layers.Dropout(rate=drop_rate)

    def call(self, inputs, training=None, **kwargs):
        x = self.bn1(inputs, training=training)
        x = tf.nn.relu(x)
        x = self.conv1(x)
        x = self.bn2(x, training=training)
        x = tf.nn.relu(x)
        x = self.conv2(x)
        x = self.dropout(x, training=training)
        return x

# %%
class DenseBlock(tf.keras.layers.Layer):
    def __init__(self, num_layers, growth_rate, drop_rate):
        super(DenseBlock, self).__init__()
        self.num_layers = num_layers
        self.growth_rate = growth_rate
        self.drop_rate = drop_rate
        self.features_list = []

    def _make_layer(self, x, training):
        y = BottleNeck(growth_rate=self.growth_rate, drop_rate=self.drop_rate)(x, training=training)
        self.features_list.append(y)
        y = tf.concat(self.features_list, axis=-1)
        return y

    def call(self, inputs, training=None, **kwargs):
        self.features_list.append(inputs)
        x = self._make_layer(inputs, training=training)
        for i in range(1, self.num_layers):
            x = self._make_layer(x, training=training)
        self.features_list.clear()
        return x

# %%
class TransitionLayer(tf.keras.layers.Layer):
    def __init__(self, out_channels):
        super(TransitionLayer, self).__init__()
        self.bn = tf.keras.layers.BatchNormalization()
        self.conv = tf.keras.layers.Conv2D(filters=out_channels,
                                           kernel_size=(1, 1),
                                           strides=1,
                                           padding="same")
        self.pool = tf.keras.layers.MaxPool2D(pool_size=(2, 2),
                                              strides=2,
                                              padding="same")

    def call(self, inputs, training=None, **kwargs):
        x = self.bn(inputs, training=training)
        x = tf.nn.relu(x)
        x = self.conv(x)
        x = self.pool(x)
        return x

# %%
class DenseNet(tf.keras.Model):
    def __init__(self, num_init_features, growth_rate, block_layers, compression_rate, drop_rate):
        super(DenseNet, self).__init__()
        self.conv = tf.keras.layers.Conv2D(filters=num_init_features,
                                           kernel_size=(7, 7),
                                           strides=2,
                                           padding="same")
        self.bn = tf.keras.layers.BatchNormalization()
        self.pool = tf.keras.layers.MaxPool2D(pool_size=(3, 3),
                                              strides=2,
                                              padding="same")
        self.num_channels = num_init_features
        self.dense_block_1 = DenseBlock(num_layers=block_layers[0], growth_rate=growth_rate, drop_rate=drop_rate)
        self.num_channels += growth_rate * block_layers[0]
        self.num_channels = compression_rate * self.num_channels
        self.transition_1 = TransitionLayer(out_channels=int(self.num_channels))
        self.dense_block_2 = DenseBlock(num_layers=block_layers[1], growth_rate=growth_rate, drop_rate=drop_rate)
        self.num_channels += growth_rate * block_layers[1]
        self.num_channels = compression_rate * self.num_channels
        self.transition_2 = TransitionLayer(out_channels=int(self.num_channels))
        self.dense_block_3 = DenseBlock(num_layers=block_layers[2], growth_rate=growth_rate, drop_rate=drop_rate)
        self.num_channels += growth_rate * block_layers[2]
        self.num_channels = compression_rate * self.num_channels
        self.transition_3 = TransitionLayer(out_channels=int(self.num_channels))
        self.dense_block_4 = DenseBlock(num_layers=block_layers[3], growth_rate=growth_rate, drop_rate=drop_rate)

        self.avgpool = tf.keras.layers.GlobalAveragePooling2D()
        self.fc = tf.keras.layers.Dense(units=NUM_CLASSES,
                                        activation=tf.keras.activations.softmax)

    def call(self, inputs, training=None, mask=None):
        x = self.conv(inputs)
        x = self.bn(x, training=training)
        x = tf.nn.relu(x)
        x = self.pool(x)

        x = self.dense_block_1(x, training=training)
        x = self.transition_1(x, training=training)
        x = self.dense_block_2(x, training=training)
        x = self.transition_2(x, training=training)
        x = self.dense_block_3(x, training=training)
        x = self.transition_3(x, training=training)
        x = self.dense_block_4(x, training=training)

        x = self.avgpool(x)
        x = self.fc(x)

        return x
    
    def build_graph(self, input_shape): 
        input_shape_nobatch = input_shape[1:]
        self.build(input_shape)
        inputs = tf.keras.Input(shape=input_shape_nobatch)
        
        if not hasattr(self, 'call'):
            raise AttributeError("User should define 'call' method in sub-class model!")
        
        _ = self.call(inputs)

# %%
def densenet_121():
    return DenseNet(num_init_features=64, growth_rate=32,
                    block_layers=[6, 12, 24, 16], compression_rate=0.5,
                    drop_rate=0.5)


def densenet_169():
    return DenseNet(num_init_features=64, growth_rate=32,
                    block_layers=[6, 12, 32, 32], compression_rate=0.5,
                    drop_rate=0.5)


def densenet_201():
    return DenseNet(num_init_features=64, growth_rate=32,
                    block_layers=[6, 12, 48, 32], compression_rate=0.5,
                    drop_rate=0.5)


def densenet_264():
    return DenseNet(num_init_features=64, growth_rate=32,
                    block_layers=[6, 12, 64, 48], compression_rate=0.5,
                    drop_rate=0.5)

# %%
def prepare_dataset():
    cifar10 = tf.keras.datasets.cifar10
    (x_train, y_train), (x_test, y_test) = cifar10.load_data()

    x_train = x_train.astype('float32')
    x_test = x_test.astype('float32')

    x_train = tf.convert_to_tensor(x_train)
    x_test = tf.convert_to_tensor(x_test)

    y_train = tf.convert_to_tensor(y_train)
    y_test = tf.convert_to_tensor(y_test)

    print("### Dataset Shape ###")
    print('x_train shape:', x_train.shape)
    print('x_test shape:', x_test.shape)
    print('y_train shape:', y_train.shape)
    print('y_test shape:', y_test.shape)

    return x_train, x_test, y_train, y_test

# %%
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if logs.get('accuracy'):
            if (logs.get('accuracy') > 0.99):
                print("\nReached 99% accuracy so cancelling training!")
                self.model.stop_training = True

# %%
def print_model_summary(network):
    network.build_graph((1, IMAGE_HEIGHT, IMAGE_WIDTH, CHANNELS))
    network.summary()

# %%
# GPU settings
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    print("### Using GPU ###")
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)

x_train, x_test, y_train, y_test = prepare_dataset()

model = densenet_121()
print_model_summary(model)

initial_learning_rate = 0.1
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=100000,
    decay_rate=0.96,
    staircase=True)

model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=lr_schedule,
                                                momentum=0.0,
                                                nesterov=False),
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])

print('\n### Fit model on training data ###')
callbacks = myCallback()
history = model.fit(x_train, y_train, epochs=1500, validation_split=0.1, batch_size=1024, callbacks=[callbacks])
print('\nhistory dict:', history.history)

model.evaluate(x_test, y_test, verbose=2)

print('\nhistory dict:', history.history)

# Evaluate the model on the test data using `evaluate`
print('\n# Evaluate on test data')
results = model.evaluate(x_test, y_test, batch_size=128)
print('test loss, test acc:', results)

# Generate predictions (probabilities -- the output of the last layer)
# on new data using `predict`
print('\n# Generate predictions for 3 samples')
predictions = model.predict(x_test[:3])
print('predictions:', predictions.argmax(axis=1))
print('Answer:', y_test[:3])
# Out:
# ### Using GPU ###
# ### Dataset Shape ###
# x_train shape: (50000, 32, 32, 3)
# x_test shape: (10000, 32, 32, 3)
# y_train shape: (50000, 1)
# y_test shape: (10000, 1)
# Model: "dense_net"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 16, 16, 64)        9472
# _________________________________________________________________
# batch_normalization (BatchNo (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 8, 8, 64)          0
# _________________________________________________________________
# dense_block (DenseBlock)     (None, 8, 8, 256)         0
# _________________________________________________________________
# transition_layer (Transition (None, 4, 4, 128)         33920
# _________________________________________________________________
# dense_block_1 (DenseBlock)   (None, 4, 4, 512)         0
# _________________________________________________________________
# transition_layer_1 (Transiti (None, 2, 2, 256)         133376
# _________________________________________________________________
# dense_block_2 (DenseBlock)   (None, 2, 2, 1024)        0
# _________________________________________________________________
# transition_layer_2 (Transiti (None, 1, 1, 512)         528896
# _________________________________________________________________
# dense_block_3 (DenseBlock)   (None, 1, 1, 1024)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 10)                10250
# =================================================================
# Total params: 716,170
# Trainable params: 712,458
# Non-trainable params: 3,712
# _________________________________________________________________
#
# ### Fit model on training data ###
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1500
# 45000/45000 [==============================] - 75s 2ms/sample - loss: 2.7377 - accuracy: 0.1159 - val_loss: 2.9397 - val_accuracy: 0.0988
# Epoch 2/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 2.3653 - accuracy: 0.1430 - val_loss: 2.5255 - val_accuracy: 0.1170
# Epoch 3/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 2.2838 - accuracy: 0.1690 - val_loss: 2.3057 - val_accuracy: 0.1390
# Epoch 4/1500
# 45000/45000 [==============================] - 74s 2ms/sample - loss: 2.1918 - accuracy: 0.1961 - val_loss: 2.3180 - val_accuracy: 0.1286
# Epoch 5/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 2.0954 - accuracy: 0.2228 - val_loss: 2.4300 - val_accuracy: 0.1118
# Epoch 6/1500
# 45000/45000 [==============================] - 74s 2ms/sample - loss: 2.0109 - accuracy: 0.2438 - val_loss: 2.3003 - val_accuracy: 0.1282
# Epoch 7/1500
# 45000/45000 [==============================] - 74s 2ms/sample - loss: 1.9374 - accuracy: 0.2667 - val_loss: 2.1937 - val_accuracy: 0.1590
# Epoch 8/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.8788 - accuracy: 0.2853 - val_loss: 2.0370 - val_accuracy: 0.2316
# Epoch 9/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.8355 - accuracy: 0.3030 - val_loss: 2.2896 - val_accuracy: 0.1426
# Epoch 10/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.8021 - accuracy: 0.3152 - val_loss: 1.9530 - val_accuracy: 0.2576
# Epoch 11/1500
# 45000/45000 [==============================] - 74s 2ms/sample - loss: 1.7714 - accuracy: 0.3270 - val_loss: 2.0184 - val_accuracy: 0.2264
# Epoch 12/1500
# 45000/45000 [==============================] - 74s 2ms/sample - loss: 1.7421 - accuracy: 0.3401 - val_loss: 1.8772 - val_accuracy: 0.2806
# Epoch 13/1500
# 45000/45000 [==============================] - 74s 2ms/sample - loss: 1.7175 - accuracy: 0.3515 - val_loss: 2.1060 - val_accuracy: 0.2266
# Epoch 14/1500
# 45000/45000 [==============================] - 74s 2ms/sample - loss: 1.6967 - accuracy: 0.3608 - val_loss: 1.7756 - val_accuracy: 0.3286
# Epoch 15/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.6704 - accuracy: 0.3709 - val_loss: 1.8548 - val_accuracy: 0.3234
# Epoch 16/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.6509 - accuracy: 0.3769 - val_loss: 1.8219 - val_accuracy: 0.3146
# Epoch 17/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.6285 - accuracy: 0.3863 - val_loss: 1.6704 - val_accuracy: 0.3682
# Epoch 18/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.6141 - accuracy: 0.3949 - val_loss: 1.7403 - val_accuracy: 0.3558
# Epoch 19/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.5943 - accuracy: 0.4022 - val_loss: 1.8293 - val_accuracy: 0.3326
# Epoch 20/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.5759 - accuracy: 0.4101 - val_loss: 1.7599 - val_accuracy: 0.3438
# Epoch 21/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.5556 - accuracy: 0.4184 - val_loss: 1.6740 - val_accuracy: 0.3724
# Epoch 22/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.5432 - accuracy: 0.4227 - val_loss: 1.7933 - val_accuracy: 0.3614
# Epoch 23/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.5265 - accuracy: 0.4299 - val_loss: 1.6298 - val_accuracy: 0.3902
# Epoch 24/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.5077 - accuracy: 0.4372 - val_loss: 1.7482 - val_accuracy: 0.3506
# Epoch 25/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.4994 - accuracy: 0.4425 - val_loss: 1.6165 - val_accuracy: 0.3972
# Epoch 26/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.4820 - accuracy: 0.4470 - val_loss: 1.6382 - val_accuracy: 0.4034
# Epoch 27/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.4737 - accuracy: 0.4539 - val_loss: 1.5805 - val_accuracy: 0.4204
# Epoch 28/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.4532 - accuracy: 0.4629 - val_loss: 1.5399 - val_accuracy: 0.4302
# Epoch 29/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.4440 - accuracy: 0.4673 - val_loss: 1.6501 - val_accuracy: 0.4072
# Epoch 30/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.4236 - accuracy: 0.4722 - val_loss: 1.6605 - val_accuracy: 0.4192
# Epoch 31/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.4207 - accuracy: 0.4739 - val_loss: 1.6012 - val_accuracy: 0.4056
# Epoch 32/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.4054 - accuracy: 0.4801 - val_loss: 1.7621 - val_accuracy: 0.3732
# Epoch 33/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.3934 - accuracy: 0.4871 - val_loss: 1.4873 - val_accuracy: 0.4588
# Epoch 34/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.3786 - accuracy: 0.4945 - val_loss: 1.6388 - val_accuracy: 0.4274
# Epoch 35/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.3644 - accuracy: 0.4979 - val_loss: 1.7607 - val_accuracy: 0.3820
# Epoch 36/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.3628 - accuracy: 0.4992 - val_loss: 1.8386 - val_accuracy: 0.3632
# Epoch 37/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.3472 - accuracy: 0.5069 - val_loss: 1.9372 - val_accuracy: 0.3562
# Epoch 38/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.3357 - accuracy: 0.5130 - val_loss: 1.5494 - val_accuracy: 0.4486
# Epoch 39/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.3216 - accuracy: 0.5182 - val_loss: 1.4044 - val_accuracy: 0.4904
# Epoch 40/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.3129 - accuracy: 0.5183 - val_loss: 1.5969 - val_accuracy: 0.4330
# Epoch 41/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.3179 - accuracy: 0.5200 - val_loss: 1.8255 - val_accuracy: 0.4050
# Epoch 42/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.3003 - accuracy: 0.5237 - val_loss: 1.6511 - val_accuracy: 0.4076
# Epoch 43/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.2920 - accuracy: 0.5286 - val_loss: 1.5913 - val_accuracy: 0.4270
# Epoch 44/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.2833 - accuracy: 0.5321 - val_loss: 1.4834 - val_accuracy: 0.4742
# Epoch 45/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.2765 - accuracy: 0.5335 - val_loss: 1.4525 - val_accuracy: 0.4908
# Epoch 46/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.2691 - accuracy: 0.5357 - val_loss: 1.3991 - val_accuracy: 0.4914
# Epoch 47/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.2551 - accuracy: 0.5434 - val_loss: 1.4750 - val_accuracy: 0.4768
# Epoch 48/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.2498 - accuracy: 0.5434 - val_loss: 1.4786 - val_accuracy: 0.4778
# Epoch 49/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.2393 - accuracy: 0.5514 - val_loss: 1.3450 - val_accuracy: 0.5166
# Epoch 50/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.2303 - accuracy: 0.5535 - val_loss: 1.3517 - val_accuracy: 0.5100
# Epoch 51/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.2220 - accuracy: 0.5552 - val_loss: 1.7157 - val_accuracy: 0.4362
# Epoch 52/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.2198 - accuracy: 0.5584 - val_loss: 1.3265 - val_accuracy: 0.5178
# Epoch 53/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.2150 - accuracy: 0.5586 - val_loss: 1.2983 - val_accuracy: 0.5306
# Epoch 54/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.1989 - accuracy: 0.5678 - val_loss: 1.8111 - val_accuracy: 0.4282
# Epoch 55/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.1954 - accuracy: 0.5674 - val_loss: 1.3844 - val_accuracy: 0.5080
# Epoch 56/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.1886 - accuracy: 0.5726 - val_loss: 1.3813 - val_accuracy: 0.5118
# Epoch 57/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.1798 - accuracy: 0.5738 - val_loss: 1.3244 - val_accuracy: 0.5274
# Epoch 58/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.1711 - accuracy: 0.5784 - val_loss: 1.2807 - val_accuracy: 0.5468
# Epoch 59/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.1639 - accuracy: 0.5791 - val_loss: 1.3659 - val_accuracy: 0.5014
# Epoch 60/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.1556 - accuracy: 0.5830 - val_loss: 1.3886 - val_accuracy: 0.5218
# Epoch 61/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.1500 - accuracy: 0.5858 - val_loss: 1.3983 - val_accuracy: 0.5058
# Epoch 62/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.1486 - accuracy: 0.5873 - val_loss: 1.5818 - val_accuracy: 0.4808
# Epoch 63/1500
# 45000/45000 [==============================] - 74s 2ms/sample - loss: 1.1297 - accuracy: 0.5929 - val_loss: 1.5861 - val_accuracy: 0.4816
# Epoch 64/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.1349 - accuracy: 0.5903 - val_loss: 2.4588 - val_accuracy: 0.3200
# Epoch 65/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.1256 - accuracy: 0.5928 - val_loss: 1.2183 - val_accuracy: 0.5690
# Epoch 66/1500
# 45000/45000 [==============================] - 74s 2ms/sample - loss: 1.1165 - accuracy: 0.5967 - val_loss: 1.3285 - val_accuracy: 0.5320
# Epoch 67/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.1107 - accuracy: 0.5992 - val_loss: 1.3821 - val_accuracy: 0.5292
# Epoch 68/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.1068 - accuracy: 0.6030 - val_loss: 1.7961 - val_accuracy: 0.4178
# Epoch 69/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.1035 - accuracy: 0.6023 - val_loss: 1.9820 - val_accuracy: 0.4196
# Epoch 70/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.0962 - accuracy: 0.6043 - val_loss: 1.3069 - val_accuracy: 0.5462
# Epoch 71/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.0850 - accuracy: 0.6075 - val_loss: 1.1662 - val_accuracy: 0.5948
# Epoch 72/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.0821 - accuracy: 0.6095 - val_loss: 1.1466 - val_accuracy: 0.5930
# Epoch 73/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.0762 - accuracy: 0.6159 - val_loss: 1.4415 - val_accuracy: 0.5126
# Epoch 74/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.0664 - accuracy: 0.6168 - val_loss: 1.1518 - val_accuracy: 0.5942
# Epoch 75/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.0654 - accuracy: 0.6176 - val_loss: 1.1155 - val_accuracy: 0.6028
# Epoch 76/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.0596 - accuracy: 0.6192 - val_loss: 1.4305 - val_accuracy: 0.5128
# Epoch 77/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.0518 - accuracy: 0.6201 - val_loss: 1.2447 - val_accuracy: 0.5692
# Epoch 78/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.0445 - accuracy: 0.6270 - val_loss: 1.3173 - val_accuracy: 0.5514
# Epoch 79/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.0451 - accuracy: 0.6242 - val_loss: 1.2123 - val_accuracy: 0.5626
# Epoch 80/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.0351 - accuracy: 0.6299 - val_loss: 1.2221 - val_accuracy: 0.5746
# Epoch 81/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.0350 - accuracy: 0.6274 - val_loss: 1.3633 - val_accuracy: 0.5322
# Epoch 82/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.0289 - accuracy: 0.6295 - val_loss: 1.4252 - val_accuracy: 0.5230
# Epoch 83/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.0278 - accuracy: 0.6310 - val_loss: 1.2162 - val_accuracy: 0.5742
# Epoch 84/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.0118 - accuracy: 0.6376 - val_loss: 1.1480 - val_accuracy: 0.5990
# Epoch 85/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.0141 - accuracy: 0.6369 - val_loss: 1.3632 - val_accuracy: 0.5218
# Epoch 86/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.0064 - accuracy: 0.6396 - val_loss: 1.4078 - val_accuracy: 0.5392
# Epoch 87/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 1.0060 - accuracy: 0.6408 - val_loss: 1.1570 - val_accuracy: 0.6000
# Epoch 88/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.9980 - accuracy: 0.6440 - val_loss: 1.8273 - val_accuracy: 0.4454
# Epoch 89/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.9948 - accuracy: 0.6440 - val_loss: 1.1675 - val_accuracy: 0.5884
# Epoch 90/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.9882 - accuracy: 0.6443 - val_loss: 1.4459 - val_accuracy: 0.5142
# Epoch 91/1500
# 45000/45000 [==============================] - 74s 2ms/sample - loss: 0.9855 - accuracy: 0.6484 - val_loss: 1.2450 - val_accuracy: 0.5702
# Epoch 92/1500
# 45000/45000 [==============================] - 74s 2ms/sample - loss: 0.9815 - accuracy: 0.6496 - val_loss: 1.3123 - val_accuracy: 0.5598
# Epoch 93/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.9738 - accuracy: 0.6505 - val_loss: 1.0832 - val_accuracy: 0.6198
# Epoch 94/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.9689 - accuracy: 0.6544 - val_loss: 1.2185 - val_accuracy: 0.5836
# Epoch 95/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.9661 - accuracy: 0.6546 - val_loss: 1.2830 - val_accuracy: 0.5728
# Epoch 96/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.9594 - accuracy: 0.6570 - val_loss: 1.1175 - val_accuracy: 0.6074
# Epoch 97/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.9547 - accuracy: 0.6595 - val_loss: 1.3286 - val_accuracy: 0.5408
# Epoch 98/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.9518 - accuracy: 0.6602 - val_loss: 1.0946 - val_accuracy: 0.6110
# Epoch 99/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.9440 - accuracy: 0.6638 - val_loss: 1.3342 - val_accuracy: 0.5530
# Epoch 100/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.9442 - accuracy: 0.6640 - val_loss: 1.3559 - val_accuracy: 0.5436
# Epoch 101/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.9416 - accuracy: 0.6640 - val_loss: 1.3367 - val_accuracy: 0.5524
# Epoch 102/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.9347 - accuracy: 0.6649 - val_loss: 1.6867 - val_accuracy: 0.4676
# Epoch 103/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.9312 - accuracy: 0.6676 - val_loss: 2.2719 - val_accuracy: 0.3800
# Epoch 104/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.9319 - accuracy: 0.6667 - val_loss: 1.4246 - val_accuracy: 0.5320
# Epoch 105/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.9214 - accuracy: 0.6726 - val_loss: 2.5286 - val_accuracy: 0.3216
# Epoch 106/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.9183 - accuracy: 0.6728 - val_loss: 1.3890 - val_accuracy: 0.5292
# Epoch 107/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.9160 - accuracy: 0.6741 - val_loss: 1.0720 - val_accuracy: 0.6280
# Epoch 108/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.9044 - accuracy: 0.6766 - val_loss: 1.9643 - val_accuracy: 0.4644
# Epoch 109/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.9074 - accuracy: 0.6762 - val_loss: 1.1833 - val_accuracy: 0.5936
# Epoch 110/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.8983 - accuracy: 0.6783 - val_loss: 1.2549 - val_accuracy: 0.5738
# Epoch 111/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.8975 - accuracy: 0.6811 - val_loss: 1.1733 - val_accuracy: 0.5956
# Epoch 112/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.8951 - accuracy: 0.6814 - val_loss: 1.0989 - val_accuracy: 0.6152
# Epoch 113/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.8960 - accuracy: 0.6795 - val_loss: 1.0087 - val_accuracy: 0.6510
# Epoch 114/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.8864 - accuracy: 0.6854 - val_loss: 1.1062 - val_accuracy: 0.6196
# Epoch 115/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.8840 - accuracy: 0.6838 - val_loss: 1.2855 - val_accuracy: 0.5656
# Epoch 116/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.8786 - accuracy: 0.6864 - val_loss: 1.6851 - val_accuracy: 0.4714
# Epoch 117/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.8805 - accuracy: 0.6865 - val_loss: 1.2355 - val_accuracy: 0.5866
# Epoch 118/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.8705 - accuracy: 0.6887 - val_loss: 1.1370 - val_accuracy: 0.6114
# Epoch 119/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.8687 - accuracy: 0.6910 - val_loss: 1.1392 - val_accuracy: 0.6112
# Epoch 120/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.8626 - accuracy: 0.6930 - val_loss: 1.1964 - val_accuracy: 0.5954
# Epoch 121/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.8609 - accuracy: 0.6926 - val_loss: 1.2483 - val_accuracy: 0.5820
# Epoch 122/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.8572 - accuracy: 0.6944 - val_loss: 1.0911 - val_accuracy: 0.6250
# Epoch 123/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.8540 - accuracy: 0.6994 - val_loss: 1.8244 - val_accuracy: 0.4570
# Epoch 124/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.8561 - accuracy: 0.6949 - val_loss: 1.3351 - val_accuracy: 0.5690
# Epoch 125/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.8500 - accuracy: 0.6963 - val_loss: 1.3473 - val_accuracy: 0.5786
# Epoch 126/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.8435 - accuracy: 0.7016 - val_loss: 1.1968 - val_accuracy: 0.5836
# Epoch 127/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.8423 - accuracy: 0.7004 - val_loss: 1.6251 - val_accuracy: 0.5098
# Epoch 128/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.8346 - accuracy: 0.7032 - val_loss: 1.0606 - val_accuracy: 0.6366
# Epoch 129/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.8322 - accuracy: 0.7033 - val_loss: 1.0184 - val_accuracy: 0.6446
# Epoch 130/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.8283 - accuracy: 0.7063 - val_loss: 1.7015 - val_accuracy: 0.5156
# Epoch 131/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.8314 - accuracy: 0.7055 - val_loss: 1.6335 - val_accuracy: 0.4960
# Epoch 132/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.8237 - accuracy: 0.7063 - val_loss: 1.0146 - val_accuracy: 0.6532
# Epoch 133/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.8214 - accuracy: 0.7098 - val_loss: 1.1327 - val_accuracy: 0.6322
# Epoch 134/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.8130 - accuracy: 0.7120 - val_loss: 1.1449 - val_accuracy: 0.6188
# Epoch 135/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.8127 - accuracy: 0.7117 - val_loss: 1.0574 - val_accuracy: 0.6422
# Epoch 136/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.8055 - accuracy: 0.7157 - val_loss: 1.2933 - val_accuracy: 0.5940
# Epoch 137/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.8040 - accuracy: 0.7163 - val_loss: 1.1200 - val_accuracy: 0.6238
# Epoch 138/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.8025 - accuracy: 0.7163 - val_loss: 0.9785 - val_accuracy: 0.6654
# Epoch 139/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.7976 - accuracy: 0.7164 - val_loss: 1.1976 - val_accuracy: 0.5956
# Epoch 140/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.7999 - accuracy: 0.7159 - val_loss: 1.0470 - val_accuracy: 0.6478
# Epoch 141/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.7953 - accuracy: 0.7197 - val_loss: 1.2102 - val_accuracy: 0.5936
# Epoch 142/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.7827 - accuracy: 0.7222 - val_loss: 1.1165 - val_accuracy: 0.6280
# Epoch 143/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.7908 - accuracy: 0.7178 - val_loss: 1.2776 - val_accuracy: 0.6008
# Epoch 144/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.7850 - accuracy: 0.7223 - val_loss: 0.9640 - val_accuracy: 0.6710
# Epoch 145/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.7811 - accuracy: 0.7217 - val_loss: 1.0257 - val_accuracy: 0.6510
# Epoch 146/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.7779 - accuracy: 0.7244 - val_loss: 0.9910 - val_accuracy: 0.6612
# Epoch 147/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.7736 - accuracy: 0.7254 - val_loss: 0.9860 - val_accuracy: 0.6634
# Epoch 148/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.7734 - accuracy: 0.7242 - val_loss: 1.2316 - val_accuracy: 0.5954
# Epoch 149/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.7737 - accuracy: 0.7245 - val_loss: 1.0329 - val_accuracy: 0.6496
# Epoch 150/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.7615 - accuracy: 0.7303 - val_loss: 0.9541 - val_accuracy: 0.6780
# Epoch 151/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.7617 - accuracy: 0.7293 - val_loss: 0.9294 - val_accuracy: 0.6860
# Epoch 152/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.7631 - accuracy: 0.7292 - val_loss: 1.2591 - val_accuracy: 0.5882
# Epoch 153/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.7566 - accuracy: 0.7320 - val_loss: 1.0187 - val_accuracy: 0.6558
# Epoch 154/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.7552 - accuracy: 0.7341 - val_loss: 1.5409 - val_accuracy: 0.5274
# Epoch 155/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.7490 - accuracy: 0.7346 - val_loss: 1.2056 - val_accuracy: 0.5978
# Epoch 156/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.7442 - accuracy: 0.7352 - val_loss: 0.9731 - val_accuracy: 0.6768
# Epoch 157/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.7396 - accuracy: 0.7377 - val_loss: 1.2220 - val_accuracy: 0.6042
# Epoch 158/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.7361 - accuracy: 0.7406 - val_loss: 1.2236 - val_accuracy: 0.6106
# Epoch 159/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.7352 - accuracy: 0.7423 - val_loss: 1.0946 - val_accuracy: 0.6406
# Epoch 160/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.7307 - accuracy: 0.7422 - val_loss: 1.1125 - val_accuracy: 0.6372
# Epoch 161/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.7319 - accuracy: 0.7414 - val_loss: 1.2102 - val_accuracy: 0.6060
# Epoch 162/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.7301 - accuracy: 0.7415 - val_loss: 1.4667 - val_accuracy: 0.5546
# Epoch 163/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.7211 - accuracy: 0.7447 - val_loss: 1.1729 - val_accuracy: 0.6180
# Epoch 164/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.7209 - accuracy: 0.7465 - val_loss: 1.2012 - val_accuracy: 0.6132
# Epoch 165/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.7229 - accuracy: 0.7439 - val_loss: 1.5889 - val_accuracy: 0.5464
# Epoch 166/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.7184 - accuracy: 0.7458 - val_loss: 1.0438 - val_accuracy: 0.6582
# Epoch 167/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.7199 - accuracy: 0.7437 - val_loss: 1.5054 - val_accuracy: 0.5506
# Epoch 168/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.7085 - accuracy: 0.7499 - val_loss: 0.9649 - val_accuracy: 0.6726
# Epoch 169/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.7078 - accuracy: 0.7478 - val_loss: 1.0382 - val_accuracy: 0.6574
# Epoch 170/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.7091 - accuracy: 0.7473 - val_loss: 0.9542 - val_accuracy: 0.6784
# Epoch 171/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.7000 - accuracy: 0.7507 - val_loss: 1.0158 - val_accuracy: 0.6554
# Epoch 172/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.7052 - accuracy: 0.7498 - val_loss: 1.0191 - val_accuracy: 0.6674
# Epoch 173/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.6968 - accuracy: 0.7523 - val_loss: 1.1163 - val_accuracy: 0.6378
# Epoch 174/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.6878 - accuracy: 0.7553 - val_loss: 0.9560 - val_accuracy: 0.6806
# Epoch 175/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.6916 - accuracy: 0.7545 - val_loss: 1.1752 - val_accuracy: 0.6156
# Epoch 176/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.6872 - accuracy: 0.7552 - val_loss: 1.0486 - val_accuracy: 0.6574
# Epoch 177/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.6825 - accuracy: 0.7595 - val_loss: 1.0877 - val_accuracy: 0.6442
# Epoch 178/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.6824 - accuracy: 0.7574 - val_loss: 1.3683 - val_accuracy: 0.5866
# Epoch 179/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.6783 - accuracy: 0.7587 - val_loss: 1.1514 - val_accuracy: 0.6456
# Epoch 180/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.6779 - accuracy: 0.7602 - val_loss: 1.1382 - val_accuracy: 0.6298
# Epoch 181/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.6718 - accuracy: 0.7618 - val_loss: 0.9611 - val_accuracy: 0.6796
# Epoch 182/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.6700 - accuracy: 0.7616 - val_loss: 1.0356 - val_accuracy: 0.6684
# Epoch 183/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.6621 - accuracy: 0.7656 - val_loss: 0.9450 - val_accuracy: 0.6848
# Epoch 184/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.6682 - accuracy: 0.7624 - val_loss: 1.2259 - val_accuracy: 0.6232
# Epoch 185/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.6581 - accuracy: 0.7665 - val_loss: 1.4779 - val_accuracy: 0.5752
# Epoch 186/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.6643 - accuracy: 0.7661 - val_loss: 0.9578 - val_accuracy: 0.6844
# Epoch 187/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.6534 - accuracy: 0.7685 - val_loss: 0.9315 - val_accuracy: 0.6918
# Epoch 188/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.6551 - accuracy: 0.7678 - val_loss: 1.2428 - val_accuracy: 0.6034
# Epoch 189/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.6509 - accuracy: 0.7702 - val_loss: 0.9258 - val_accuracy: 0.6904
# Epoch 190/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.6453 - accuracy: 0.7711 - val_loss: 1.2328 - val_accuracy: 0.6142
# Epoch 191/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.6458 - accuracy: 0.7712 - val_loss: 1.2090 - val_accuracy: 0.6168
# Epoch 192/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.6419 - accuracy: 0.7738 - val_loss: 0.9347 - val_accuracy: 0.6902
# Epoch 193/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.6410 - accuracy: 0.7738 - val_loss: 1.0695 - val_accuracy: 0.6526
# Epoch 194/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.6369 - accuracy: 0.7727 - val_loss: 1.3586 - val_accuracy: 0.5850
# Epoch 195/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.6345 - accuracy: 0.7780 - val_loss: 0.9337 - val_accuracy: 0.6916
# Epoch 196/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.6302 - accuracy: 0.7777 - val_loss: 1.1256 - val_accuracy: 0.6328
# Epoch 197/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.6242 - accuracy: 0.7811 - val_loss: 0.8965 - val_accuracy: 0.7086
# Epoch 198/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.6288 - accuracy: 0.7772 - val_loss: 0.9706 - val_accuracy: 0.6756
# Epoch 199/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.6217 - accuracy: 0.7796 - val_loss: 0.9928 - val_accuracy: 0.6744
# Epoch 200/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.6192 - accuracy: 0.7812 - val_loss: 1.0580 - val_accuracy: 0.6624
# Epoch 201/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.6163 - accuracy: 0.7829 - val_loss: 1.1600 - val_accuracy: 0.6344
# Epoch 202/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.6098 - accuracy: 0.7844 - val_loss: 1.3722 - val_accuracy: 0.5778
# Epoch 203/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.6081 - accuracy: 0.7837 - val_loss: 1.1791 - val_accuracy: 0.6372
# Epoch 204/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.6092 - accuracy: 0.7856 - val_loss: 0.9425 - val_accuracy: 0.6940
# Epoch 205/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.6067 - accuracy: 0.7829 - val_loss: 1.2367 - val_accuracy: 0.6210
# Epoch 206/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.6022 - accuracy: 0.7849 - val_loss: 1.0705 - val_accuracy: 0.6596
# Epoch 207/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5992 - accuracy: 0.7872 - val_loss: 0.9717 - val_accuracy: 0.6814
# Epoch 208/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.6031 - accuracy: 0.7864 - val_loss: 0.8725 - val_accuracy: 0.7050
# Epoch 209/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5969 - accuracy: 0.7876 - val_loss: 0.9696 - val_accuracy: 0.6766
# Epoch 210/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5905 - accuracy: 0.7907 - val_loss: 1.1879 - val_accuracy: 0.6274
# Epoch 211/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5887 - accuracy: 0.7914 - val_loss: 1.0335 - val_accuracy: 0.6836
# Epoch 212/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5805 - accuracy: 0.7933 - val_loss: 0.9951 - val_accuracy: 0.6854
# Epoch 213/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5786 - accuracy: 0.7952 - val_loss: 0.9113 - val_accuracy: 0.7020
# Epoch 214/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5824 - accuracy: 0.7936 - val_loss: 1.0808 - val_accuracy: 0.6640
# Epoch 215/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5847 - accuracy: 0.7923 - val_loss: 1.0587 - val_accuracy: 0.6656
# Epoch 216/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5732 - accuracy: 0.7958 - val_loss: 1.0980 - val_accuracy: 0.6450
# Epoch 217/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5755 - accuracy: 0.7948 - val_loss: 0.9572 - val_accuracy: 0.6922
# Epoch 218/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5708 - accuracy: 0.7968 - val_loss: 1.2384 - val_accuracy: 0.6244
# Epoch 219/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5643 - accuracy: 0.7983 - val_loss: 1.0317 - val_accuracy: 0.6764
# Epoch 220/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5689 - accuracy: 0.7986 - val_loss: 1.2630 - val_accuracy: 0.6210
# Epoch 221/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5632 - accuracy: 0.8013 - val_loss: 1.1823 - val_accuracy: 0.6358
# Epoch 222/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5553 - accuracy: 0.8027 - val_loss: 1.2132 - val_accuracy: 0.6314
# Epoch 223/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5603 - accuracy: 0.8033 - val_loss: 1.0034 - val_accuracy: 0.6860
# Epoch 224/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5545 - accuracy: 0.8028 - val_loss: 1.1942 - val_accuracy: 0.6420
# Epoch 225/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5535 - accuracy: 0.8014 - val_loss: 0.9135 - val_accuracy: 0.7030
# Epoch 226/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5540 - accuracy: 0.8030 - val_loss: 1.3323 - val_accuracy: 0.6120
# Epoch 227/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5437 - accuracy: 0.8065 - val_loss: 1.1737 - val_accuracy: 0.6478
# Epoch 228/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5383 - accuracy: 0.8093 - val_loss: 1.4525 - val_accuracy: 0.6014
# Epoch 229/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5459 - accuracy: 0.8064 - val_loss: 1.1101 - val_accuracy: 0.6650
# Epoch 230/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5324 - accuracy: 0.8129 - val_loss: 0.9234 - val_accuracy: 0.7000
# Epoch 231/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5370 - accuracy: 0.8087 - val_loss: 1.2397 - val_accuracy: 0.6304
# Epoch 232/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5320 - accuracy: 0.8105 - val_loss: 0.9352 - val_accuracy: 0.7026
# Epoch 233/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5274 - accuracy: 0.8115 - val_loss: 1.0434 - val_accuracy: 0.6842
# Epoch 234/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5238 - accuracy: 0.8138 - val_loss: 1.1834 - val_accuracy: 0.6456
# Epoch 235/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5217 - accuracy: 0.8137 - val_loss: 1.0547 - val_accuracy: 0.6702
# Epoch 236/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5236 - accuracy: 0.8138 - val_loss: 1.2142 - val_accuracy: 0.6424
# Epoch 237/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5187 - accuracy: 0.8152 - val_loss: 2.0019 - val_accuracy: 0.5102
# Epoch 238/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5144 - accuracy: 0.8170 - val_loss: 1.0093 - val_accuracy: 0.6888
# Epoch 239/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5140 - accuracy: 0.8182 - val_loss: 1.2822 - val_accuracy: 0.6268
# Epoch 240/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5133 - accuracy: 0.8169 - val_loss: 0.9295 - val_accuracy: 0.7150
# Epoch 241/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5081 - accuracy: 0.8183 - val_loss: 1.3256 - val_accuracy: 0.6084
# Epoch 242/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5096 - accuracy: 0.8182 - val_loss: 1.1938 - val_accuracy: 0.6480
# Epoch 243/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4993 - accuracy: 0.8226 - val_loss: 1.1901 - val_accuracy: 0.6554
# Epoch 244/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.5015 - accuracy: 0.8218 - val_loss: 1.0198 - val_accuracy: 0.6888
# Epoch 245/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4934 - accuracy: 0.8266 - val_loss: 1.0537 - val_accuracy: 0.6826
# Epoch 246/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4897 - accuracy: 0.8257 - val_loss: 0.9622 - val_accuracy: 0.7060
# Epoch 247/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4903 - accuracy: 0.8262 - val_loss: 1.0104 - val_accuracy: 0.6894
# Epoch 248/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4938 - accuracy: 0.8258 - val_loss: 1.1683 - val_accuracy: 0.6576
# Epoch 249/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4840 - accuracy: 0.8281 - val_loss: 0.9773 - val_accuracy: 0.6940
# Epoch 250/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4791 - accuracy: 0.8281 - val_loss: 1.0691 - val_accuracy: 0.6774
# Epoch 251/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4858 - accuracy: 0.8261 - val_loss: 0.9573 - val_accuracy: 0.7074
# Epoch 252/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4797 - accuracy: 0.8291 - val_loss: 1.0718 - val_accuracy: 0.6820
# Epoch 253/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4765 - accuracy: 0.8303 - val_loss: 1.0533 - val_accuracy: 0.6822
# Epoch 254/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4695 - accuracy: 0.8325 - val_loss: 1.1020 - val_accuracy: 0.6706
# Epoch 255/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4765 - accuracy: 0.8296 - val_loss: 1.2715 - val_accuracy: 0.6458
# Epoch 256/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4710 - accuracy: 0.8320 - val_loss: 1.1074 - val_accuracy: 0.6768
# Epoch 257/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4603 - accuracy: 0.8367 - val_loss: 1.0608 - val_accuracy: 0.6866
# Epoch 258/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4565 - accuracy: 0.8371 - val_loss: 0.9325 - val_accuracy: 0.7134
# Epoch 259/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4531 - accuracy: 0.8391 - val_loss: 1.1521 - val_accuracy: 0.6674
# Epoch 260/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4581 - accuracy: 0.8368 - val_loss: 1.1142 - val_accuracy: 0.6742
# Epoch 261/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4571 - accuracy: 0.8361 - val_loss: 1.3648 - val_accuracy: 0.6266
# Epoch 262/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4591 - accuracy: 0.8358 - val_loss: 1.3217 - val_accuracy: 0.6310
# Epoch 263/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4472 - accuracy: 0.8410 - val_loss: 1.5750 - val_accuracy: 0.5900
# Epoch 264/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4590 - accuracy: 0.8363 - val_loss: 1.3644 - val_accuracy: 0.6294
# Epoch 265/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4395 - accuracy: 0.8439 - val_loss: 1.1185 - val_accuracy: 0.6678
# Epoch 266/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4370 - accuracy: 0.8431 - val_loss: 1.2128 - val_accuracy: 0.6538
# Epoch 267/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4334 - accuracy: 0.8455 - val_loss: 1.3101 - val_accuracy: 0.6436
# Epoch 268/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4390 - accuracy: 0.8443 - val_loss: 1.1225 - val_accuracy: 0.6782
# Epoch 269/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4335 - accuracy: 0.8446 - val_loss: 1.3799 - val_accuracy: 0.6320
# Epoch 270/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4279 - accuracy: 0.8463 - val_loss: 1.2000 - val_accuracy: 0.6706
# Epoch 271/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4293 - accuracy: 0.8464 - val_loss: 1.4102 - val_accuracy: 0.6188
# Epoch 272/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4247 - accuracy: 0.8502 - val_loss: 1.0098 - val_accuracy: 0.6984
# Epoch 273/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4196 - accuracy: 0.8514 - val_loss: 1.3170 - val_accuracy: 0.6392
# Epoch 274/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4156 - accuracy: 0.8509 - val_loss: 1.4034 - val_accuracy: 0.6342
# Epoch 275/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4129 - accuracy: 0.8533 - val_loss: 1.1129 - val_accuracy: 0.6824
# Epoch 276/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4184 - accuracy: 0.8499 - val_loss: 1.1298 - val_accuracy: 0.6742
# Epoch 277/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4174 - accuracy: 0.8511 - val_loss: 1.0933 - val_accuracy: 0.6884
# Epoch 278/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4075 - accuracy: 0.8555 - val_loss: 1.1252 - val_accuracy: 0.6888
# Epoch 279/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4086 - accuracy: 0.8532 - val_loss: 1.1898 - val_accuracy: 0.6674
# Epoch 280/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.4026 - accuracy: 0.8576 - val_loss: 1.1737 - val_accuracy: 0.6778
# Epoch 281/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.3918 - accuracy: 0.8605 - val_loss: 1.1357 - val_accuracy: 0.6776
# Epoch 282/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.3926 - accuracy: 0.8598 - val_loss: 1.1161 - val_accuracy: 0.6930
# Epoch 283/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.3868 - accuracy: 0.8604 - val_loss: 1.5828 - val_accuracy: 0.6082
# Epoch 284/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.3961 - accuracy: 0.8579 - val_loss: 1.2778 - val_accuracy: 0.6524
# Epoch 285/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.3966 - accuracy: 0.8589 - val_loss: 1.0546 - val_accuracy: 0.6974
# Epoch 286/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.3841 - accuracy: 0.8616 - val_loss: 1.9379 - val_accuracy: 0.5462
# Epoch 287/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.3804 - accuracy: 0.8634 - val_loss: 1.1318 - val_accuracy: 0.6826
# Epoch 288/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.3878 - accuracy: 0.8607 - val_loss: 1.0691 - val_accuracy: 0.6974
# Epoch 289/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.3748 - accuracy: 0.8659 - val_loss: 0.9990 - val_accuracy: 0.7128
# Epoch 290/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.3827 - accuracy: 0.8617 - val_loss: 1.2347 - val_accuracy: 0.6712
# Epoch 291/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.3797 - accuracy: 0.8638 - val_loss: 1.8785 - val_accuracy: 0.5750
# Epoch 292/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.3748 - accuracy: 0.8641 - val_loss: 1.2756 - val_accuracy: 0.6592
# Epoch 293/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.3709 - accuracy: 0.8662 - val_loss: 1.2345 - val_accuracy: 0.6698
# Epoch 294/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.3664 - accuracy: 0.8689 - val_loss: 1.3603 - val_accuracy: 0.6502
# Epoch 295/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.3546 - accuracy: 0.8733 - val_loss: 1.3231 - val_accuracy: 0.6514
# Epoch 296/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.3658 - accuracy: 0.8692 - val_loss: 1.4127 - val_accuracy: 0.6440
# Epoch 297/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.3548 - accuracy: 0.8749 - val_loss: 1.1526 - val_accuracy: 0.6858
# Epoch 298/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.3560 - accuracy: 0.8708 - val_loss: 1.5495 - val_accuracy: 0.6192
# Epoch 299/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.3541 - accuracy: 0.8727 - val_loss: 1.7756 - val_accuracy: 0.5856
# Epoch 300/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.3462 - accuracy: 0.8758 - val_loss: 1.2320 - val_accuracy: 0.6686
# Epoch 301/1500
# ...
# Epoch 420/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.0663 - accuracy: 0.9822 - val_loss: 1.6412 - val_accuracy: 0.7028
# Epoch 421/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.0685 - accuracy: 0.9811 - val_loss: 1.5979 - val_accuracy: 0.7112
# Epoch 422/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.0689 - accuracy: 0.9800 - val_loss: 1.6809 - val_accuracy: 0.7038
# Epoch 423/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.0664 - accuracy: 0.9817 - val_loss: 1.6022 - val_accuracy: 0.7188
# Epoch 424/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.0702 - accuracy: 0.9790 - val_loss: 1.6346 - val_accuracy: 0.7064
# Epoch 425/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.0732 - accuracy: 0.9779 - val_loss: 1.8738 - val_accuracy: 0.6708
# Epoch 426/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.0669 - accuracy: 0.9805 - val_loss: 1.5948 - val_accuracy: 0.7154
# Epoch 427/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.0635 - accuracy: 0.9820 - val_loss: 1.6160 - val_accuracy: 0.7082
# Epoch 428/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.0623 - accuracy: 0.9824 - val_loss: 1.6713 - val_accuracy: 0.7124
# Epoch 429/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.0593 - accuracy: 0.9839 - val_loss: 1.6473 - val_accuracy: 0.7106
# Epoch 430/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.0619 - accuracy: 0.9825 - val_loss: 1.9728 - val_accuracy: 0.6792
# Epoch 431/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.0579 - accuracy: 0.9846 - val_loss: 1.6745 - val_accuracy: 0.7124
# Epoch 432/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.0524 - accuracy: 0.9877 - val_loss: 1.6751 - val_accuracy: 0.7148
# Epoch 433/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.0529 - accuracy: 0.9869 - val_loss: 1.7833 - val_accuracy: 0.6924
# Epoch 434/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.0520 - accuracy: 0.9867 - val_loss: 1.6619 - val_accuracy: 0.7070
# Epoch 435/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.0548 - accuracy: 0.9856 - val_loss: 1.7334 - val_accuracy: 0.7048
# Epoch 436/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.0519 - accuracy: 0.9863 - val_loss: 1.8275 - val_accuracy: 0.6926
# Epoch 437/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.0559 - accuracy: 0.9837 - val_loss: 1.6756 - val_accuracy: 0.7142
# Epoch 438/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.0453 - accuracy: 0.9892 - val_loss: 1.6748 - val_accuracy: 0.7166
# Epoch 439/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.0465 - accuracy: 0.9885 - val_loss: 1.6404 - val_accuracy: 0.7138
# Epoch 440/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.0488 - accuracy: 0.9872 - val_loss: 1.8078 - val_accuracy: 0.6980
# Epoch 441/1500
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.0452 - accuracy: 0.9889 - val_loss: 1.7464 - val_accuracy: 0.7102
# Epoch 442/1500
# 44032/45000 [============================>.] - ETA: 1s - loss: 0.0444 - accuracy: 0.9900
# Reached 99% accuracy so cancelling training!
# 45000/45000 [==============================] - 73s 2ms/sample - loss: 0.0444 - accuracy: 0.9900 - val_loss: 1.6777 - val_accuracy: 0.7198
#
# history dict: {'loss': [2.737706036843194, 2.365289028167725, 2.2838134432474773, 2.1918446654425727, 2.0953566450330947, 2.0108596756193373, 1.937411028289795, 1.878830226220025, 1.835526297484504, 1.802133373260498, 1.7713647003809612, 1.7421015484703912, 1.7174761914147272, 1.6967490636401705, 1.6703651131100126, 1.65090719487932, 1.628482229338752, 1.6140626823213364, 1.5942828046586779, 1.5759410623338488, 1.5555738201989069, 1.5432473668840196, 1.5264959496604071, 1.5076922081629436, 1.4994235100852118, 1.4819844037585788, 1.4737261624654134, 1.4531545957989163, 1.4439668891482884, 1.423618915939331, 1.420724436039395, 1.4054122832404243, 1.393440122795105, 1.3785895584742227, 1.364434857643975, 1.3628378510369195, 1.3471690735287136, 1.3357195006052653, 1.3215956913630167, 1.312903962855869, 1.3179113380855985, 1.3003098608228896, 1.2919891833411323, 1.2832869088490804, 1.2765205810758802, 1.2690983471340602, 1.2551142485512627, 1.2497690861596003, 1.2392813130696614, 1.2302796833462186, 1.221951835017734, 1.219769054645962, 1.2149931470659043, 1.198869976319207, 1.195430660396152, 1.1886097364849515, 1.1798436746173435, 1.1710963159561156, 1.1638783191680908, 1.1556317037158543, 1.1500134159723918, 1.1486458631515504, 1.1296636984295316, 1.1348862667507595, 1.1256137072881063, 1.1165387468126085, 1.1106576683256362, 1.10675506278144, 1.103540140024821, 1.0961977314843072, 1.085012825287713, 1.0820680088467067, 1.0762105523851182, 1.0664278503417968, 1.0653574984020657, 1.0596394896189372, 1.0518092193603517, 1.0445421005884807, 1.0451013515048557, 1.0350634359995523, 1.0350255192226834, 1.028896003405253, 1.0277736566119724, 1.0117962902492947, 1.0141109429253472, 1.0064306090037027, 1.005966086991628, 0.9979793189154731, 0.9947585385640462, 0.9882199064890543, 0.9855209046681722, 0.9814953165054321, 0.9738210776646932, 0.9689221418804592, 0.9660586450152927, 0.9593895475811428, 0.9547109548780653, 0.9517633026229011, 0.9439792235056559, 0.9442456025759379, 0.941643216143714, 0.9347229287147522, 0.9312276078859965, 0.9318540009286669, 0.9213874282307095, 0.9182707307179769, 0.9159766091452705, 0.9044263218667772, 0.9073796231587727, 0.898310673904419, 0.8974783199946086, 0.8950873792966206, 0.8959674878756205, 0.8863847724808587, 0.884017431195577, 0.8785955107794867, 0.8804599199083116, 0.8705146560774909, 0.868729733742608, 0.8625523229175144, 0.8609107654995388, 0.8572228636847602, 0.8540336146672567, 0.8560671258502537, 0.8499774953948127, 0.8434953888363308, 0.842307574028439, 0.8346233792410956, 0.832219164858924, 0.8283091508547465, 0.8313820641941494, 0.8237274521827698, 0.8213915810585022, 0.8129693146917555, 0.8126705422931247, 0.8054705723020765, 0.8039608538309733, 0.8025091838412814, 0.7975658366733127, 0.7998840224795871, 0.7953251994556851, 0.7826968997531467, 0.7907581386566163, 0.7850295999526977, 0.7811279442045423, 0.7778654241455926, 0.7736378495428298, 0.7733636448224386, 0.7737098169962565, 0.7614613968849182, 0.7617309938006931, 0.7631371820555793, 0.7566166896714105, 0.7552195314407348, 0.7489898356225756, 0.7442282076835632, 0.7396319132592943, 0.7360608982510037, 0.7352177579138014, 0.7306702135403951, 0.7319330979135301, 0.7301453157742818, 0.721128171465132, 0.7209274831347995, 0.7229115180333455, 0.7183614821222093, 0.7198815609402127, 0.7085200965881348, 0.7077915995703803, 0.7090980677922567, 0.6999606295161777, 0.7052028673277961, 0.6968261896027459, 0.6878421890364753, 0.691594712638855, 0.6872280915260315, 0.6825094606717428, 0.6823866227467855, 0.6783013391918606, 0.6778600278324551, 0.6717689455138313, 0.6699690244462755, 0.6621047461509705, 0.6682040852122837, 0.6580846572875977, 0.6643035245683458, 0.6534247451464336, 0.6550919597095913, 0.6509355523957147, 0.6453316536903382, 0.6457638756328159, 0.6418655784077114, 0.6409542374398973, 0.636931632010142, 0.6345133225017123, 0.6302281616104973, 0.6242052065531413, 0.6287653040144179, 0.6217498035960727, 0.6192280331293741, 0.6163210 ...
# 10000/1 - 355s - loss: 2.0228 - accuracy: 0.6987
#
# history dict: {'loss': [2.737706036843194, 2.365289028167725, 2.2838134432474773, 2.1918446654425727, 2.0953566450330947, 2.0108596756193373, 1.937411028289795, 1.878830226220025, 1.835526297484504, 1.802133373260498, 1.7713647003809612, 1.7421015484703912, 1.7174761914147272, 1.6967490636401705, 1.6703651131100126, 1.65090719487932, 1.628482229338752, 1.6140626823213364, 1.5942828046586779, 1.5759410623338488, 1.5555738201989069, 1.5432473668840196, 1.5264959496604071, 1.5076922081629436, 1.4994235100852118, 1.4819844037585788, 1.4737261624654134, 1.4531545957989163, 1.4439668891482884, 1.423618915939331, 1.420724436039395, 1.4054122832404243, 1.393440122795105, 1.3785895584742227, 1.364434857643975, 1.3628378510369195, 1.3471690735287136, 1.3357195006052653, 1.3215956913630167, 1.312903962855869, 1.3179113380855985, 1.3003098608228896, 1.2919891833411323, 1.2832869088490804, 1.2765205810758802, 1.2690983471340602, 1.2551142485512627, 1.2497690861596003, 1.2392813130696614, 1.2302796833462186, 1.221951835017734, 1.219769054645962, 1.2149931470659043, 1.198869976319207, 1.195430660396152, 1.1886097364849515, 1.1798436746173435, 1.1710963159561156, 1.1638783191680908, 1.1556317037158543, 1.1500134159723918, 1.1486458631515504, 1.1296636984295316, 1.1348862667507595, 1.1256137072881063, 1.1165387468126085, 1.1106576683256362, 1.10675506278144, 1.103540140024821, 1.0961977314843072, 1.085012825287713, 1.0820680088467067, 1.0762105523851182, 1.0664278503417968, 1.0653574984020657, 1.0596394896189372, 1.0518092193603517, 1.0445421005884807, 1.0451013515048557, 1.0350634359995523, 1.0350255192226834, 1.028896003405253, 1.0277736566119724, 1.0117962902492947, 1.0141109429253472, 1.0064306090037027, 1.005966086991628, 0.9979793189154731, 0.9947585385640462, 0.9882199064890543, 0.9855209046681722, 0.9814953165054321, 0.9738210776646932, 0.9689221418804592, 0.9660586450152927, 0.9593895475811428, 0.9547109548780653, 0.9517633026229011, 0.9439792235056559, 0.9442456025759379, 0.941643216143714, 0.9347229287147522, 0.9312276078859965, 0.9318540009286669, 0.9213874282307095, 0.9182707307179769, 0.9159766091452705, 0.9044263218667772, 0.9073796231587727, 0.898310673904419, 0.8974783199946086, 0.8950873792966206, 0.8959674878756205, 0.8863847724808587, 0.884017431195577, 0.8785955107794867, 0.8804599199083116, 0.8705146560774909, 0.868729733742608, 0.8625523229175144, 0.8609107654995388, 0.8572228636847602, 0.8540336146672567, 0.8560671258502537, 0.8499774953948127, 0.8434953888363308, 0.842307574028439, 0.8346233792410956, 0.832219164858924, 0.8283091508547465, 0.8313820641941494, 0.8237274521827698, 0.8213915810585022, 0.8129693146917555, 0.8126705422931247, 0.8054705723020765, 0.8039608538309733, 0.8025091838412814, 0.7975658366733127, 0.7998840224795871, 0.7953251994556851, 0.7826968997531467, 0.7907581386566163, 0.7850295999526977, 0.7811279442045423, 0.7778654241455926, 0.7736378495428298, 0.7733636448224386, 0.7737098169962565, 0.7614613968849182, 0.7617309938006931, 0.7631371820555793, 0.7566166896714105, 0.7552195314407348, 0.7489898356225756, 0.7442282076835632, 0.7396319132592943, 0.7360608982510037, 0.7352177579138014, 0.7306702135403951, 0.7319330979135301, 0.7301453157742818, 0.721128171465132, 0.7209274831347995, 0.7229115180333455, 0.7183614821222093, 0.7198815609402127, 0.7085200965881348, 0.7077915995703803, 0.7090980677922567, 0.6999606295161777, 0.7052028673277961, 0.6968261896027459, 0.6878421890364753, 0.691594712638855, 0.6872280915260315, 0.6825094606717428, 0.6823866227467855, 0.6783013391918606, 0.6778600278324551, 0.6717689455138313, 0.6699690244462755, 0.6621047461509705, 0.6682040852122837, 0.6580846572875977, 0.6643035245683458, 0.6534247451464336, 0.6550919597095913, 0.6509355523957147, 0.6453316536903382, 0.6457638756328159, 0.6418655784077114, 0.6409542374398973, 0.636931632010142, 0.6345133225017123, 0.6302281616104973, 0.6242052065531413, 0.6287653040144179, 0.6217498035960727, 0.6192280331293741, 0.6163210 ...
#
# # Evaluate on test data
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# test loss, test acc: [1.755268715286255, 0.699]
#
# # Generate predictions for 3 samples
# predictions: [3 8 8]
# Answer: tf.Tensor(
# [[3]
#  [8]
#  [8]], shape=(3, 1), dtype=uint8)
